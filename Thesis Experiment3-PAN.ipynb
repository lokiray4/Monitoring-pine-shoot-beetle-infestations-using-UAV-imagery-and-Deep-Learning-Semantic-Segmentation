# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from pathlib import Path
from PIL import Image
from sklearn.metrics import precision_score, recall_score, f1_score, jaccard_score
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <08E12B12-6183-307E-BDA0-374FA8EBA2C9> /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/image.so
#   Expected in:     <709C1DF5-D253-3C66-87E2-C99FD3A259DF> /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/lib/libtorch_cpu.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
import torch.nn.functional as F

class PAN(nn.Module):
    def __init__(self, num_classes=1, pretrained_backbone=True, backbone_weights_path=None):
        super(PAN, self).__init__()
        # Load resnet50 as the backbone
        self.backbone = resnet50(pretrained=False)  
        if pretrained_backbone and backbone_weights_path:
            state_dict = torch.load(backbone_weights_path)
            self.backbone.load_state_dict(state_dict, strict=False)

        # Encoder layers
        self.encoder = nn.Sequential(*list(self.backbone.children())[:-2])
        
        # Head with upsampling to match input size
        self.head = nn.Sequential(
            nn.Conv2d(2048, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, num_classes, kernel_size=1)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.head(x)
        x = F.interpolate(x, size=(256, 256), mode='bilinear', align_corners=False)  # Upsample to input size
        return x

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from pathlib import Path
from PIL import Image
from sklearn.metrics import precision_score, recall_score, f1_score, jaccard_score

# 自定义数据集类
class ContrailDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        super().__init__()
        self.image_dir = Path(image_dir)
        self.mask_dir = Path(mask_dir)
        self.files = [f for f in self.image_dir.iterdir() if f.is_file() and f.suffix in ['.png', '.jpg', '.jpeg']]
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        image_path = self.files[idx]
        mask_path = self.mask_dir / image_path.name

        image = Image.open(image_path).convert('RGB')  # 读取为RGB图像
        mask = Image.open(mask_path).convert('L')  # 读取为灰度图像

        if self.transform:
            image = self.transform(image)
            mask = transforms.ToTensor()(mask)

        mask = (mask > 0).float()  # 将掩码二值化
        return image, mask.unsqueeze(0)  # 在channel维度增加一个维度

# 定义Dice损失函数
class DiceLoss(nn.Module):
    def forward(self, inputs, targets, smooth=1):
        inputs = torch.sigmoid(inputs)
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        intersection = (inputs * targets).sum()
        dice = (2. * intersection + smooth) / (inputs.sum() + targets.sum() + smooth)
        return 1 - dice

# 计算 Precision, Recall, F1 Score, IoU
def calculate_metrics(preds, labels):
    preds = (torch.sigmoid(preds) > 0.5).cpu().numpy().flatten()  # 二值化预测
    labels = labels.cpu().numpy().flatten()

    precision = precision_score(labels, preds, zero_division=1)
    recall = recall_score(labels, preds, zero_division=1)
    f1 = f1_score(labels, preds, zero_division=1)
    iou = jaccard_score(labels, preds, zero_division=1)

    return precision, recall, f1, iou

# 计算平均 IoU（mIoU），对于二分类问题，mIoU 就是 IoU 本身
def calculate_mIoU(preds, labels):
    preds = (torch.sigmoid(preds) > 0.5).cpu().numpy()
    labels = labels.cpu().numpy()

    ious = []
    for i in range(preds.shape[0]):  # 针对每一张图片
        iou = jaccard_score(labels[i].flatten(), preds[i].flatten(), zero_division=1)
        ious.append(iou)
    
    return sum(ious) / len(ious)

def calculate_accuracy(preds, labels):
    # 使用Sigmoid并将输出二值化
    preds = (torch.sigmoid(preds) > 0.5).float()  # 二值化预测
    # 确保预测和标签维度一致
    preds = preds.view(-1)
    labels = labels.view(-1)

    # 计算正确的预测像素总数
    correct = (preds == labels).sum().item()
    # 计算总像素数
    total = labels.size(0)

    # 返回准确率
    acc = correct / total
    return acc

# 训练函数
def train_model(model, train_loader, valid_loader, loss_fn, optimizer, num_epochs, device):
    best_f1 = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_acc = 0

        # Training phase
        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_fn(outputs, masks)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            acc = calculate_accuracy(outputs, masks)
            train_acc += acc

        # Validation phase
        model.eval()
        valid_loss = 0
        valid_acc = 0
        valid_precision = 0
        valid_recall = 0
        valid_f1 = 0
        valid_iou = 0
        valid_miou = 0

        with torch.no_grad():
            for images, masks in valid_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)

                loss = loss_fn(outputs, masks)
                valid_loss += loss.item()

                acc = calculate_accuracy(outputs, masks)
                valid_acc += acc

                precision, recall, f1, iou = calculate_metrics(outputs, masks)
                valid_precision += precision
                valid_recall += recall
                valid_f1 += f1
                valid_iou += iou
                valid_miou += calculate_mIoU(outputs, masks)

        # 平均值
        avg_train_loss = train_loss / len(train_loader)
        avg_train_acc = train_acc / len(train_loader)
        avg_valid_loss = valid_loss / len(valid_loader)
        avg_valid_acc = valid_acc / len(valid_loader)
        avg_valid_precision = valid_precision / len(valid_loader)
        avg_valid_recall = valid_recall / len(valid_loader)
        avg_valid_f1 = valid_f1 / len(valid_loader)
        avg_valid_iou = valid_iou / len(valid_loader)
        avg_valid_miou = valid_miou / len(valid_loader)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_acc:.4f}, '
              f'Val Loss: {avg_valid_loss:.4f}, Val Acc: {avg_valid_acc:.4f}, '
              f'Precision: {avg_valid_precision:.4f}, Recall: {avg_valid_recall:.4f}, '
              f'F1 Score: {avg_valid_f1:.4f}, IoU: {avg_valid_iou:.4f}, mIoU: {avg_valid_miou:.4f}')

        # 保存最好的模型
        if avg_valid_f1 > best_f1:
            best_f1 = avg_valid_f1
            torch.save(model.state_dict(), 'PAN_model.pth')

# 设置参数
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
image_dir = '/Users/camus/Desktop/trainX/image'
mask_dir = '/Users/camus/Desktop/trainX/maskimage'

batch_size = 4
num_epochs = 100

# 图像预处理，直接使用256x256的尺寸
transform = transforms.Compose([
    transforms.Resize((256, 256)),  # 将图像调整为256x256
    transforms.ToTensor(),
])

# 加载数据集
dataset = ContrailDataset(image_dir, mask_dir, transform=transform)
train_size = int(0.75 * len(dataset))
valid_size = len(dataset) - train_size
train_dataset, valid_dataset = torch.utils.data.random_split(dataset, [train_size, valid_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size)

# 指定权重文件的路径
backbone_weights_path = '/Volumes/Vettel/学习/预训练模型/resnet50-0676ba61.pth'

model = PAN(num_classes=1, pretrained_backbone=True, backbone_weights_path=backbone_weights_path).to(device)
loss_fn = DiceLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 训练模型
train_model(model, train_loader, valid_loader, loss_fn, optimizer, num_epochs, device)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/100], Train Loss: 0.8135, Train Acc: 0.1064, Val Loss: 0.8221, Val Acc: 0.0984, Precision: 0.0984, Recall: 1.0000, F1 Score: 0.1779, IoU: 0.0984, mIoU: 0.0984
# Epoch [2/100], Train Loss: 0.8179, Train Acc: 0.1017, Val Loss: 0.8221, Val Acc: 0.0984, Precision: 0.0984, Recall: 1.0000, F1 Score: 0.1779, IoU: 0.0984, mIoU: 0.0984
# Epoch [3/100], Train Loss: 0.7314, Train Acc: 0.4189, Val Loss: 0.7912, Val Acc: 0.4656, Precision: 0.1230, Recall: 0.7296, F1 Score: 0.2088, IoU: 0.1179, mIoU: 0.1233
# Epoch [4/100], Train Loss: 0.3745, Train Acc: 0.9154, Val Loss: 0.3327, Val Acc: 0.9344, Precision: 0.6580, Recall: 0.7139, F1 Score: 0.6675, IoU: 0.5086, mIoU: 0.5049
# Epoch [5/100], Train Loss: 0.3107, Train Acc: 0.9344, Val Loss: 0.2908, Val Acc: 0.9359, Precision: 0.6430, Recall: 0.8269, F1 Score: 0.7093, IoU: 0.5572, mIoU: 0.5590
# Epoch [6/100], Train Loss: 0.2931, Train Acc: 0.9382, Val Loss: 0.2574, Val Acc: 0.9457, Precision: 0.6987, Recall: 0.8261, F1 Score: 0.7426, IoU: 0.5993, mIoU: 0.6133
# Epoch [7/100], Train Loss: 0.2836, Train Acc: 0.9409, Val Loss: 0.5893, Val Acc: 0.9250, Precision: 0.9048, Recall: 0.2909, F1 Score: 0.4105, IoU: 0.2768, mIoU: 0.2633
# Epoch [8/100], Train Loss: 0.2854, Train Acc: 0.9406, Val Loss: 0.3131, Val Acc: 0.9438, Precision: 0.7450, Recall: 0.6638, F1 Score: 0.6870, IoU: 0.5335, mIoU: 0.5184
# Epoch [9/100], Train Loss: 0.2895, Train Acc: 0.9394, Val Loss: 0.3966, Val Acc: 0.8884, Precision: 0.5041, Recall: 0.8370, F1 Score: 0.6035, IoU: 0.4510, mIoU: 0.5014
# Epoch [10/100], Train Loss: 0.2916, Train Acc: 0.9397, Val Loss: 0.3428, Val Acc: 0.9258, Precision: 0.6433, Recall: 0.7197, F1 Score: 0.6573, IoU: 0.5038, mIoU: 0.5353
# Epoch [11/100], Train Loss: 0.2728, Train Acc: 0.9441, Val Loss: 0.2564, Val Acc: 0.9429, Precision: 0.6619, Recall: 0.8876, F1 Score: 0.7435, IoU: 0.5972, mIoU: 0.6004
# Epoch [12/100], Train Loss: 0.2663, Train Acc: 0.9446, Val Loss: 0.2945, Val Acc: 0.9269, Precision: 0.5871, Recall: 0.9317, F1 Score: 0.7055, IoU: 0.5548, mIoU: 0.5715
# Epoch [13/100], Train Loss: 0.2616, Train Acc: 0.9458, Val Loss: 0.2837, Val Acc: 0.9320, Precision: 0.6107, Recall: 0.9117, F1 Score: 0.7163, IoU: 0.5683, mIoU: 0.5893
# Epoch [14/100], Train Loss: 0.2503, Train Acc: 0.9462, Val Loss: 0.2819, Val Acc: 0.9454, Precision: 0.7160, Recall: 0.7583, F1 Score: 0.7181, IoU: 0.5709, mIoU: 0.5699
# Epoch [15/100], Train Loss: 0.2304, Train Acc: 0.9521, Val Loss: 0.2573, Val Acc: 0.9432, Precision: 0.6613, Recall: 0.8835, F1 Score: 0.7427, IoU: 0.5961, mIoU: 0.6073
# Epoch [16/100], Train Loss: 0.2321, Train Acc: 0.9525, Val Loss: 0.2438, Val Acc: 0.9541, Precision: 0.7798, Recall: 0.7664, F1 Score: 0.7563, IoU: 0.6171, mIoU: 0.6286
# Epoch [17/100], Train Loss: 0.2385, Train Acc: 0.9500, Val Loss: 0.3123, Val Acc: 0.9442, Precision: 0.7725, Recall: 0.6467, F1 Score: 0.6877, IoU: 0.5329, mIoU: 0.5460
# Epoch [18/100], Train Loss: 0.2367, Train Acc: 0.9515, Val Loss: 0.2370, Val Acc: 0.9554, Precision: 0.7844, Recall: 0.7740, F1 Score: 0.7631, IoU: 0.6266, mIoU: 0.6394
# Epoch [19/100], Train Loss: 0.2431, Train Acc: 0.9503, Val Loss: 0.3130, Val Acc: 0.9192, Precision: 0.5587, Recall: 0.9459, F1 Score: 0.6869, IoU: 0.5320, mIoU: 0.5398
# Epoch [20/100], Train Loss: 0.2267, Train Acc: 0.9513, Val Loss: 0.2187, Val Acc: 0.9558, Precision: 0.7480, Recall: 0.8435, F1 Score: 0.7813, IoU: 0.6458, mIoU: 0.6533
# Epoch [21/100], Train Loss: 0.1940, Train Acc: 0.9605, Val Loss: 0.2760, Val Acc: 0.9500, Precision: 0.7686, Recall: 0.7148, F1 Score: 0.7240, IoU: 0.5778, mIoU: 0.5762
# Epoch [22/100], Train Loss: 0.1990, Train Acc: 0.9594, Val Loss: 0.2450, Val Acc: 0.9553, Precision: 0.8030, Recall: 0.7384, F1 Score: 0.7551, IoU: 0.6157, mIoU: 0.6183
# Epoch [23/100], Train Loss: 0.2092, Train Acc: 0.9589, Val Loss: 0.2900, Val Acc: 0.9506, Precision: 0.8292, Recall: 0.6493, F1 Score: 0.7100, IoU: 0.5614, mIoU: 0.5566
# Epoch [24/100], Train Loss: 0.2001, Train Acc: 0.9600, Val Loss: 0.2412, Val Acc: 0.9514, Precision: 0.7245, Recall: 0.8362, F1 Score: 0.7589, IoU: 0.6224, mIoU: 0.6377
# Epoch [25/100], Train Loss: 0.2005, Train Acc: 0.9591, Val Loss: 0.2563, Val Acc: 0.9445, Precision: 0.6731, Recall: 0.8661, F1 Score: 0.7439, IoU: 0.6032, mIoU: 0.6252
# Epoch [26/100], Train Loss: 0.2151, Train Acc: 0.9565, Val Loss: 0.3016, Val Acc: 0.9460, Precision: 0.7424, Recall: 0.6883, F1 Score: 0.6983, IoU: 0.5487, mIoU: 0.5203
# Epoch [27/100], Train Loss: 0.2110, Train Acc: 0.9568, Val Loss: 0.2892, Val Acc: 0.9442, Precision: 0.7166, Recall: 0.7417, F1 Score: 0.7108, IoU: 0.5609, mIoU: 0.5739
# Epoch [28/100], Train Loss: 0.1868, Train Acc: 0.9620, Val Loss: 0.2145, Val Acc: 0.9579, Precision: 0.7694, Recall: 0.8236, F1 Score: 0.7855, IoU: 0.6516, mIoU: 0.6549
# Epoch [29/100], Train Loss: 0.1802, Train Acc: 0.9631, Val Loss: 0.2443, Val Acc: 0.9519, Precision: 0.7419, Recall: 0.8058, F1 Score: 0.7556, IoU: 0.6168, mIoU: 0.6305
# Epoch [30/100], Train Loss: 0.1903, Train Acc: 0.9615, Val Loss: 0.4673, Val Acc: 0.9304, Precision: 0.8068, Recall: 0.4295, F1 Score: 0.5326, IoU: 0.3731, mIoU: 0.4012
# Epoch [31/100], Train Loss: 0.1882, Train Acc: 0.9627, Val Loss: 0.5690, Val Acc: 0.9234, Precision: 0.8394, Recall: 0.3116, F1 Score: 0.4311, IoU: 0.2848, mIoU: 0.3053
# Epoch [32/100], Train Loss: 0.1982, Train Acc: 0.9609, Val Loss: 0.2465, Val Acc: 0.9522, Precision: 0.7497, Recall: 0.7998, F1 Score: 0.7536, IoU: 0.6176, mIoU: 0.6373
# Epoch [33/100], Train Loss: 0.1905, Train Acc: 0.9625, Val Loss: 0.2466, Val Acc: 0.9502, Precision: 0.7220, Recall: 0.8210, F1 Score: 0.7534, IoU: 0.6112, mIoU: 0.6201
# Epoch [34/100], Train Loss: 0.1694, Train Acc: 0.9656, Val Loss: 0.2454, Val Acc: 0.9513, Precision: 0.7308, Recall: 0.8284, F1 Score: 0.7546, IoU: 0.6184, mIoU: 0.6323
# Epoch [35/100], Train Loss: 0.1598, Train Acc: 0.9680, Val Loss: 0.2360, Val Acc: 0.9547, Precision: 0.7692, Recall: 0.7859, F1 Score: 0.7640, IoU: 0.6253, mIoU: 0.6234
# Epoch [36/100], Train Loss: 0.1493, Train Acc: 0.9702, Val Loss: 0.2247, Val Acc: 0.9545, Precision: 0.7472, Recall: 0.8336, F1 Score: 0.7753, IoU: 0.6379, mIoU: 0.6420
# Epoch [37/100], Train Loss: 0.1613, Train Acc: 0.9681, Val Loss: 0.3153, Val Acc: 0.9472, Precision: 0.8130, Recall: 0.6196, F1 Score: 0.6847, IoU: 0.5359, mIoU: 0.5376
# Epoch [38/100], Train Loss: 0.1488, Train Acc: 0.9700, Val Loss: 0.2447, Val Acc: 0.9545, Precision: 0.7903, Recall: 0.7629, F1 Score: 0.7553, IoU: 0.6190, mIoU: 0.6303
# Epoch [39/100], Train Loss: 0.1412, Train Acc: 0.9719, Val Loss: 0.2196, Val Acc: 0.9570, Precision: 0.7825, Recall: 0.8046, F1 Score: 0.7803, IoU: 0.6455, mIoU: 0.6504
# Epoch [40/100], Train Loss: 0.1398, Train Acc: 0.9722, Val Loss: 0.2430, Val Acc: 0.9520, Precision: 0.7379, Recall: 0.8226, F1 Score: 0.7570, IoU: 0.6207, mIoU: 0.6336
# Epoch [41/100], Train Loss: 0.1424, Train Acc: 0.9722, Val Loss: 0.2179, Val Acc: 0.9560, Precision: 0.7443, Recall: 0.8506, F1 Score: 0.7821, IoU: 0.6483, mIoU: 0.6442
# Epoch [42/100], Train Loss: 0.1385, Train Acc: 0.9728, Val Loss: 0.2426, Val Acc: 0.9538, Precision: 0.7688, Recall: 0.7838, F1 Score: 0.7574, IoU: 0.6174, mIoU: 0.6280
# Epoch [43/100], Train Loss: 0.1414, Train Acc: 0.9717, Val Loss: 0.2222, Val Acc: 0.9553, Precision: 0.7297, Recall: 0.8551, F1 Score: 0.7777, IoU: 0.6421, mIoU: 0.6458
# Epoch [44/100], Train Loss: 0.1631, Train Acc: 0.9674, Val Loss: 0.2448, Val Acc: 0.9490, Precision: 0.7087, Recall: 0.8570, F1 Score: 0.7554, IoU: 0.6177, mIoU: 0.6396
# Epoch [45/100], Train Loss: 0.1538, Train Acc: 0.9684, Val Loss: 0.2325, Val Acc: 0.9533, Precision: 0.7456, Recall: 0.8294, F1 Score: 0.7676, IoU: 0.6309, mIoU: 0.6423
# Epoch [46/100], Train Loss: 0.1407, Train Acc: 0.9732, Val Loss: 0.2377, Val Acc: 0.9517, Precision: 0.7356, Recall: 0.8360, F1 Score: 0.7624, IoU: 0.6273, mIoU: 0.6517
# Epoch [47/100], Train Loss: 0.1305, Train Acc: 0.9741, Val Loss: 0.2423, Val Acc: 0.9539, Precision: 0.7695, Recall: 0.7955, F1 Score: 0.7578, IoU: 0.6228, mIoU: 0.6340
# Epoch [48/100], Train Loss: 0.1275, Train Acc: 0.9750, Val Loss: 0.2223, Val Acc: 0.9553, Precision: 0.7535, Recall: 0.8366, F1 Score: 0.7777, IoU: 0.6427, mIoU: 0.6558
# Epoch [49/100], Train Loss: 0.1214, Train Acc: 0.9763, Val Loss: 0.2179, Val Acc: 0.9554, Precision: 0.7478, Recall: 0.8524, F1 Score: 0.7821, IoU: 0.6484, mIoU: 0.6566
# Epoch [50/100], Train Loss: 0.1257, Train Acc: 0.9750, Val Loss: 0.2494, Val Acc: 0.9522, Precision: 0.7597, Recall: 0.7859, F1 Score: 0.7507, IoU: 0.6128, mIoU: 0.6291
# Epoch [51/100], Train Loss: 0.1340, Train Acc: 0.9737, Val Loss: 0.2462, Val Acc: 0.9525, Precision: 0.7513, Recall: 0.7929, F1 Score: 0.7538, IoU: 0.6121, mIoU: 0.6149
# Epoch [52/100], Train Loss: 0.1259, Train Acc: 0.9750, Val Loss: 0.2479, Val Acc: 0.9535, Precision: 0.7816, Recall: 0.7697, F1 Score: 0.7522, IoU: 0.6183, mIoU: 0.6349
# Epoch [53/100], Train Loss: 0.1507, Train Acc: 0.9694, Val Loss: 0.4438, Val Acc: 0.9332, Precision: 0.8345, Recall: 0.4394, F1 Score: 0.5562, IoU: 0.3920, mIoU: 0.4317
# Epoch [54/100], Train Loss: 0.2037, Train Acc: 0.9591, Val Loss: 0.2374, Val Acc: 0.9506, Precision: 0.7203, Recall: 0.8436, F1 Score: 0.7626, IoU: 0.6228, mIoU: 0.6384
# Epoch [55/100], Train Loss: 0.1589, Train Acc: 0.9673, Val Loss: 0.2302, Val Acc: 0.9529, Precision: 0.7352, Recall: 0.8429, F1 Score: 0.7698, IoU: 0.6314, mIoU: 0.6437
# Epoch [56/100], Train Loss: 0.1351, Train Acc: 0.9737, Val Loss: 0.2726, Val Acc: 0.9501, Precision: 0.7764, Recall: 0.7231, F1 Score: 0.7274, IoU: 0.5829, mIoU: 0.5967
# Epoch [57/100], Train Loss: 0.1597, Train Acc: 0.9675, Val Loss: 0.2613, Val Acc: 0.9439, Precision: 0.6720, Recall: 0.8585, F1 Score: 0.7387, IoU: 0.5937, mIoU: 0.6014
# Epoch [58/100], Train Loss: 0.1529, Train Acc: 0.9690, Val Loss: 0.2421, Val Acc: 0.9548, Precision: 0.7799, Recall: 0.7737, F1 Score: 0.7578, IoU: 0.6206, mIoU: 0.6302
# Epoch [59/100], Train Loss: 0.1510, Train Acc: 0.9711, Val Loss: 0.2613, Val Acc: 0.9472, Precision: 0.7093, Recall: 0.8073, F1 Score: 0.7388, IoU: 0.5942, mIoU: 0.5915
# Epoch [60/100], Train Loss: 0.1451, Train Acc: 0.9713, Val Loss: 0.2157, Val Acc: 0.9566, Precision: 0.7539, Recall: 0.8428, F1 Score: 0.7843, IoU: 0.6516, mIoU: 0.6560
# Epoch [61/100], Train Loss: 0.1349, Train Acc: 0.9728, Val Loss: 0.3113, Val Acc: 0.9472, Precision: 0.7875, Recall: 0.6310, F1 Score: 0.6887, IoU: 0.5299, mIoU: 0.5264
# Epoch [62/100], Train Loss: 0.2086, Train Acc: 0.9571, Val Loss: 0.2509, Val Acc: 0.9516, Precision: 0.7470, Recall: 0.7842, F1 Score: 0.7490, IoU: 0.6082, mIoU: 0.6140
# Epoch [63/100], Train Loss: 0.1701, Train Acc: 0.9655, Val Loss: 0.2627, Val Acc: 0.9427, Precision: 0.6687, Recall: 0.8701, F1 Score: 0.7372, IoU: 0.5930, mIoU: 0.6133
# Epoch [64/100], Train Loss: 0.1523, Train Acc: 0.9694, Val Loss: 0.2416, Val Acc: 0.9544, Precision: 0.7866, Recall: 0.7658, F1 Score: 0.7585, IoU: 0.6190, mIoU: 0.6397
# Epoch [65/100], Train Loss: 0.1405, Train Acc: 0.9718, Val Loss: 0.2319, Val Acc: 0.9549, Precision: 0.7620, Recall: 0.8045, F1 Score: 0.7681, IoU: 0.6298, mIoU: 0.6426
# Epoch [66/100], Train Loss: 0.1854, Train Acc: 0.9656, Val Loss: 0.4558, Val Acc: 0.9135, Precision: 0.5775, Recall: 0.5567, F1 Score: 0.5442, IoU: 0.3794, mIoU: 0.4030
# Epoch [67/100], Train Loss: 0.2227, Train Acc: 0.9543, Val Loss: 0.2549, Val Acc: 0.9473, Precision: 0.7116, Recall: 0.8197, F1 Score: 0.7450, IoU: 0.5985, mIoU: 0.6063
# Epoch [68/100], Train Loss: 0.1431, Train Acc: 0.9706, Val Loss: 0.2376, Val Acc: 0.9537, Precision: 0.7698, Recall: 0.7861, F1 Score: 0.7624, IoU: 0.6219, mIoU: 0.6291
# Epoch [69/100], Train Loss: 0.1285, Train Acc: 0.9746, Val Loss: 0.2512, Val Acc: 0.9498, Precision: 0.7353, Recall: 0.8046, F1 Score: 0.7487, IoU: 0.6041, mIoU: 0.6182
# Epoch [70/100], Train Loss: 0.1294, Train Acc: 0.9750, Val Loss: 0.2714, Val Acc: 0.9490, Precision: 0.7639, Recall: 0.7386, F1 Score: 0.7286, IoU: 0.5836, mIoU: 0.6064
# Epoch [71/100], Train Loss: 0.1252, Train Acc: 0.9749, Val Loss: 0.2507, Val Acc: 0.9504, Precision: 0.7420, Recall: 0.7954, F1 Score: 0.7494, IoU: 0.6047, mIoU: 0.6154
# Epoch [72/100], Train Loss: 0.1234, Train Acc: 0.9759, Val Loss: 0.2451, Val Acc: 0.9521, Precision: 0.7597, Recall: 0.7866, F1 Score: 0.7550, IoU: 0.6129, mIoU: 0.6238
# Epoch [73/100], Train Loss: 0.1170, Train Acc: 0.9776, Val Loss: 0.2398, Val Acc: 0.9540, Precision: 0.7782, Recall: 0.7740, F1 Score: 0.7602, IoU: 0.6177, mIoU: 0.6282
# Epoch [74/100], Train Loss: 0.1194, Train Acc: 0.9770, Val Loss: 0.2414, Val Acc: 0.9532, Precision: 0.7723, Recall: 0.7781, F1 Score: 0.7586, IoU: 0.6171, mIoU: 0.6263
# Epoch [75/100], Train Loss: 0.1132, Train Acc: 0.9777, Val Loss: 0.2467, Val Acc: 0.9510, Precision: 0.7412, Recall: 0.8003, F1 Score: 0.7533, IoU: 0.6093, mIoU: 0.6171
# Epoch [76/100], Train Loss: 0.1110, Train Acc: 0.9782, Val Loss: 0.2489, Val Acc: 0.9518, Precision: 0.7571, Recall: 0.7820, F1 Score: 0.7507, IoU: 0.6076, mIoU: 0.6216
# Epoch [77/100], Train Loss: 0.1098, Train Acc: 0.9784, Val Loss: 0.2577, Val Acc: 0.9509, Precision: 0.7606, Recall: 0.7647, F1 Score: 0.7422, IoU: 0.6009, mIoU: 0.6196
# Epoch [78/100], Train Loss: 0.1183, Train Acc: 0.9778, Val Loss: 0.2494, Val Acc: 0.9526, Precision: 0.7713, Recall: 0.7666, F1 Score: 0.7508, IoU: 0.6092, mIoU: 0.6238
# Epoch [79/100], Train Loss: 0.1097, Train Acc: 0.9790, Val Loss: 0.2474, Val Acc: 0.9521, Precision: 0.7565, Recall: 0.7882, F1 Score: 0.7526, IoU: 0.6113, mIoU: 0.6259
# Epoch [80/100], Train Loss: 0.1175, Train Acc: 0.9778, Val Loss: 0.2691, Val Acc: 0.9520, Precision: 0.8112, Recall: 0.6966, F1 Score: 0.7310, IoU: 0.5857, mIoU: 0.6006
# Epoch [81/100], Train Loss: 0.1496, Train Acc: 0.9707, Val Loss: 0.2710, Val Acc: 0.9501, Precision: 0.7834, Recall: 0.7178, F1 Score: 0.7290, IoU: 0.5820, mIoU: 0.5926
# Epoch [82/100], Train Loss: 0.1411, Train Acc: 0.9714, Val Loss: 0.2583, Val Acc: 0.9533, Precision: 0.8003, Recall: 0.7286, F1 Score: 0.7417, IoU: 0.6005, mIoU: 0.6165
# Epoch [83/100], Train Loss: 0.1146, Train Acc: 0.9769, Val Loss: 0.2394, Val Acc: 0.9545, Precision: 0.7796, Recall: 0.7772, F1 Score: 0.7607, IoU: 0.6215, mIoU: 0.6339
# Epoch [84/100], Train Loss: 0.1087, Train Acc: 0.9781, Val Loss: 0.2371, Val Acc: 0.9533, Precision: 0.7560, Recall: 0.8066, F1 Score: 0.7631, IoU: 0.6242, mIoU: 0.6366
# Epoch [85/100], Train Loss: 0.1065, Train Acc: 0.9781, Val Loss: 0.2381, Val Acc: 0.9546, Precision: 0.7819, Recall: 0.7800, F1 Score: 0.7618, IoU: 0.6246, mIoU: 0.6387
# Epoch [86/100], Train Loss: 0.1062, Train Acc: 0.9790, Val Loss: 0.2297, Val Acc: 0.9557, Precision: 0.7754, Recall: 0.7955, F1 Score: 0.7704, IoU: 0.6322, mIoU: 0.6396
# Epoch [87/100], Train Loss: 0.1031, Train Acc: 0.9797, Val Loss: 0.2425, Val Acc: 0.9533, Precision: 0.7677, Recall: 0.7871, F1 Score: 0.7576, IoU: 0.6187, mIoU: 0.6353
# Epoch [88/100], Train Loss: 0.1022, Train Acc: 0.9801, Val Loss: 0.2423, Val Acc: 0.9538, Precision: 0.7670, Recall: 0.7918, F1 Score: 0.7576, IoU: 0.6214, mIoU: 0.6375
# Epoch [89/100], Train Loss: 0.0996, Train Acc: 0.9799, Val Loss: 0.2333, Val Acc: 0.9544, Precision: 0.7602, Recall: 0.8092, F1 Score: 0.7666, IoU: 0.6288, mIoU: 0.6395
# Epoch [90/100], Train Loss: 0.0993, Train Acc: 0.9806, Val Loss: 0.2429, Val Acc: 0.9536, Precision: 0.7701, Recall: 0.7856, F1 Score: 0.7572, IoU: 0.6204, mIoU: 0.6376
# Epoch [91/100], Train Loss: 0.0996, Train Acc: 0.9803, Val Loss: 0.2410, Val Acc: 0.9535, Precision: 0.7618, Recall: 0.7945, F1 Score: 0.7589, IoU: 0.6216, mIoU: 0.6358
# Epoch [92/100], Train Loss: 0.0995, Train Acc: 0.9803, Val Loss: 0.2310, Val Acc: 0.9553, Precision: 0.7728, Recall: 0.7996, F1 Score: 0.7692, IoU: 0.6319, mIoU: 0.6423
# Epoch [93/100], Train Loss: 0.0976, Train Acc: 0.9806, Val Loss: 0.2420, Val Acc: 0.9546, Precision: 0.7865, Recall: 0.7712, F1 Score: 0.7580, IoU: 0.6211, mIoU: 0.6406
# Epoch [94/100], Train Loss: 0.1030, Train Acc: 0.9799, Val Loss: 0.3034, Val Acc: 0.9475, Precision: 0.8105, Recall: 0.6401, F1 Score: 0.6965, IoU: 0.5475, mIoU: 0.5701
# Epoch [95/100], Train Loss: 0.1290, Train Acc: 0.9738, Val Loss: 0.2653, Val Acc: 0.9532, Precision: 0.8119, Recall: 0.7068, F1 Score: 0.7347, IoU: 0.5931, mIoU: 0.6051
# Epoch [96/100], Train Loss: 0.1096, Train Acc: 0.9781, Val Loss: 0.2424, Val Acc: 0.9548, Precision: 0.7845, Recall: 0.7671, F1 Score: 0.7575, IoU: 0.6188, mIoU: 0.6336
# Epoch [97/100], Train Loss: 0.1053, Train Acc: 0.9795, Val Loss: 0.2704, Val Acc: 0.9497, Precision: 0.7608, Recall: 0.7440, F1 Score: 0.7295, IoU: 0.5841, mIoU: 0.5986
# Epoch [98/100], Train Loss: 0.1104, Train Acc: 0.9780, Val Loss: 0.2447, Val Acc: 0.9518, Precision: 0.7439, Recall: 0.8097, F1 Score: 0.7552, IoU: 0.6157, mIoU: 0.6350
# Epoch [99/100], Train Loss: 0.1045, Train Acc: 0.9795, Val Loss: 0.2420, Val Acc: 0.9545, Precision: 0.7842, Recall: 0.7700, F1 Score: 0.7580, IoU: 0.6202, mIoU: 0.6363
# Epoch [100/100], Train Loss: 0.0997, Train Acc: 0.9802, Val Loss: 0.2306, Val Acc: 0.9565, Precision: 0.7870, Recall: 0.7886, F1 Score: 0.7695, IoU: 0.6361, mIoU: 0.6499
